# %%
import pandas as pd
import numpy as np
import openpyxl

FUNNEL_DATE = 20250209
MONTH_START_DATE = 20250201

#brand = 'Slazenger'
brand = 'HRX by Hrithik Roshan'

LY_START_DATE = MONTH_START_DATE - 10000 
LY_END_DATE = FUNNEL_DATE - 10000

data = pd.read_csv('../Files/DSR/PF SALES 10 FEB 2025.csv')
data = data[(data['order_created_date'] <= FUNNEL_DATE) & (data['order_created_date'] >= MONTH_START_DATE)]
LY_data = pd.read_csv('../Files/DSR/2024 SALES/FEB 2024 PF BAGWise SALES ALL BRANDS.csv')
LY_data = LY_data[ (LY_data['order_created_date'] >= LY_START_DATE) & (LY_data['order_created_date'] <= LY_END_DATE)  ]

v_data = pd.read_csv('../Files/DSR/PF VISIBILITY 10 FEB 2024.csv')
LY_v_data = pd.read_csv('../Files/DSR/2024 VISIBILITY/PF DAILY VISIBILITY FEB 2024.csv')
LY_v_data = LY_v_data[ (LY_v_data['load_date'] >= LY_START_DATE) & (LY_v_data['load_date'] <= LY_END_DATE)  ]

#REVENUE

#functions

def Quantity_Sold(dump):    
    if len(dump) == 0:
        return 'NA'
    else:
        qty = dump['quantity'].sum()
        return qty

def royaltyClean(royalty):
    if pd.isnull(royalty) == True:
        return 0
    else:
        return royalty

def computeGM_Percentage(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        r = dump['revenue'].sum()
        p = dump['purchase_price'].sum()
        t = dump['tax'].sum()
        ro = dump['royalty'].sum()
        result = round( ((r-p-t-ro) / (r)),4 )
        return result

def computeTD_Percentage(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        tmrp = dump['tot_mrp'].sum()
        r = dump['revenue'].sum()
        result = round( ((tmrp-r) / (tmrp)),4 )
        return result

data['royalty'] = data['royalty'].apply(royaltyClean)
LY_data['royalty'] = LY_data['royalty'].apply(royaltyClean)

#5 to 7
PLATFORM_TOTAL_REVENUE = round((data['revenue'].sum() / 10000000),2)
MMB_REVENUE = round((data[data['brand_type'] == 'External']['revenue'].sum() / 10000000),2)
MFB_REVENUE = round((data[data['brand_type'] == 'Private']['revenue'].sum() / 10000000),2)
LY_PLATFORM_TOTAL_REVENUE = round((LY_data['revenue'].sum() / 10000000),2)
LY_MMB_REVENUE = round((LY_data[LY_data['brand_type'] == 'External']['revenue'].sum() / 10000000),2)
LY_MFB_REVENUE = round((LY_data[LY_data['brand_type'] == 'Private']['revenue'].sum() / 10000000),2)
#9 to 11
MSA_REVENUE = round((data[data['business_unit'] == "Men's Sports Apparel"]['revenue'].sum() / 10000000),2)
WSA_REVENUE = round((data[data['business_unit'] == "Women's Sports Apparel"]['revenue'].sum() / 10000000),2)
SPORTS_WEAR_REVENUE = round((MSA_REVENUE + WSA_REVENUE),4)
LY_MSA_REVENUE = round((LY_data[LY_data['business_unit'] == "Men's Sports Apparel"]['revenue'].sum() / 10000000),2)
LY_WSA_REVENUE = round((LY_data[LY_data['business_unit'] == "Women's Sports Apparel"]['revenue'].sum() / 10000000),2)
LY_SPORTS_WEAR_REVENUE = round((LY_MSA_REVENUE + LY_WSA_REVENUE),4)
#13 to 18
HRX_TOTAL_REVENUE = round((data[ (data['master_brand'] == brand)  ]['revenue'].sum() / 10000000),4)
HRX_OR_REVENUE = round((data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ]['revenue'].sum() / 10000000 ),4)
HRX_MP_REVENUE = round((data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ]['revenue'].sum() / 10000000 ),4)
HRX_MSA_REVENUE = round((data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ]['revenue'].sum() / 10000000 ),4)
HRX_WSA_REVENUE = round((data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ]['revenue'].sum() / 10000000),4)
HRX_M_PLUS_W_TOTAL_REVENUE = round((HRX_MSA_REVENUE + HRX_WSA_REVENUE),4)
LY_HRX_TOTAL_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand)  ]['revenue'].sum() / 10000000),4)
LY_HRX_OR_REVENUE = round((LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ]['revenue'].sum() / 10000000 ),4)
LY_HRX_MP_REVENUE = round((LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ]['revenue'].sum() / 10000000 ),4)
LY_HRX_MSA_REVENUE = round((LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ]['revenue'].sum() / 10000000 ),4)
LY_HRX_WSA_REVENUE = round((LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ]['revenue'].sum() / 10000000),4)
LY_HRX_M_PLUS_W_TOTAL_REVENUE = round((LY_HRX_MSA_REVENUE + LY_HRX_WSA_REVENUE),4)
#21 to 22
HRX_MSA_OR_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ]['revenue'].sum() / 10000000),4)    
HRX_MSA_MP_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ]['revenue'].sum() / 10000000),4)    
LY_HRX_MSA_OR_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ]['revenue'].sum() / 10000000),4)    
LY_HRX_MSA_MP_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ]['revenue'].sum() / 10000000),4)    
#26 to 27
HRX_WSA_OR_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ]['revenue'].sum() / 10000000),4)    
HRX_WSA_MP_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ]['revenue'].sum() / 10000000),4)    
LY_HRX_WSA_OR_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ]['revenue'].sum() / 10000000),4)    
LY_HRX_WSA_MP_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ]['revenue'].sum() / 10000000),4)    
#31 TO 37
HRX_MSA_TSHIRTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ]['revenue'].sum() / 10000000),4)
HRX_MSA_TRACKPANTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ]['revenue'].sum() / 10000000),4)
HRX_MSA_SHORTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ]['revenue'].sum() / 10000000),4)
HRX_MSA_COORDS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ]['revenue'].sum() / 10000000),4)
HRX_MSA_TRACKSUITS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ]['revenue'].sum() / 10000000),4)
HRX_MSA_JACKETS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ]['revenue'].sum() / 10000000),4)
HRX_MSA_SWEATSHIRTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_TSHIRTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_TRACKPANTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_SHORTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_COORDS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_TRACKSUITS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_JACKETS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ]['revenue'].sum() / 10000000),4)
LY_HRX_MSA_SWEATSHIRTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ]['revenue'].sum() / 10000000),4)
#40 to 49
HRX_WSA_TSHIRTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ]['revenue'].sum() / 10000000),4)
HRX_WSA_TIGHTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ]['revenue'].sum() / 10000000),4)
HRX_WSA_TRACKPANTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ]['revenue'].sum() / 10000000),4)
HRX_WSA_BRA_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ]['revenue'].sum() / 10000000),4)
HRX_WSA_SHORTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ]['revenue'].sum() / 10000000),4)
HRX_WSA_TOPS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ]['revenue'].sum() / 10000000),4)
HRX_WSA_TROUSERS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ]['revenue'].sum() / 10000000),4)
HRX_WSA_TRACKSUITS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ]['revenue'].sum() / 10000000),4)
HRX_WSA_JACKETS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ]['revenue'].sum() / 10000000),4)
HRX_WSA_SWEATSHIRTS_REVENUE = round((data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TSHIRTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TIGHTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TRACKPANTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_BRA_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_SHORTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TOPS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TROUSERS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_TRACKSUITS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_JACKETS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ]['revenue'].sum() / 10000000),4)
LY_HRX_WSA_SWEATSHIRTS_REVENUE = round((LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ]['revenue'].sum() / 10000000),4)

#55 to 61
TEMP_OR_MSA = data[ (data['master_brand'] == brand) & (data['po_type'] == 'OR') & (data['business_unit'] == "Men's Sports Apparel") ]
OR_MSA_TSHIRTS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_TRACKPANTS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_SHORTS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_TIGHTS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_TRACKSUITS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_JACKETS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
OR_MSA_SWEATSHIRTS_REVENUE = round((TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)
LY_TEMP_OR_MSA = LY_data[ (LY_data['master_brand'] == brand) & (LY_data['po_type'] == 'OR') & (LY_data['business_unit'] == "Men's Sports Apparel") ]
LY_OR_MSA_TSHIRTS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_TRACKPANTS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_SHORTS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_TIGHTS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_TRACKSUITS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_JACKETS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
LY_OR_MSA_SWEATSHIRTS_REVENUE = round((LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)

#64 to 72
TEMP_OR_WSA = data[ (data['master_brand'] == brand) & (data['po_type'] == 'OR') & (data['business_unit'] == "Women's Sports Apparel") ]
OR_WSA_TSHIRTS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_TIGHTS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_TRACKPANTS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_BRA_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_SHORTS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_TOPS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_TROUSERS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_TRACKSUITS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
OR_WSA_JACKETS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4) #$
OR_WSA_SWEATSHIRTS_REVENUE = round((TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)
LY_TEMP_OR_WSA = LY_data[ (LY_data['master_brand'] == brand) & (LY_data['po_type'] == 'OR') & (LY_data['business_unit'] == "Women's Sports Apparel") ]
LY_OR_WSA_TSHIRTS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_TIGHTS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_TRACKPANTS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_BRA_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_SHORTS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_TOPS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_TROUSERS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_TRACKSUITS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
LY_OR_WSA_JACKETS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4) #$
LY_OR_WSA_SWEATSHIRTS_REVENUE = round((LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)

#78 to 84
TEMP_MP_MSA = data[ (data['master_brand'] == brand) & (data['po_type'] == 'MP') & (data['business_unit'] == "Men's Sports Apparel") ]
MP_MSA_TSHIRTS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_TRACKPANTS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_SHORTS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_TIGHTS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_TRACKSUITS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_JACKETS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
MP_MSA_SWEATSHIRTS_REVENUE = round((TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)
LY_TEMP_MP_MSA = LY_data[ (LY_data['master_brand'] == brand) & (LY_data['po_type'] == 'MP') & (LY_data['business_unit'] == "Men's Sports Apparel") ]
LY_MP_MSA_TSHIRTS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_TRACKPANTS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_SHORTS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_TIGHTS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_TRACKSUITS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_JACKETS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
LY_MP_MSA_SWEATSHIRTS_REVENUE = round((LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)

#87 to 95
TEMP_MP_WSA = data[ (data['master_brand'] == brand) & (data['po_type'] == 'MP') & (data['business_unit'] == "Women's Sports Apparel") ]
MP_WSA_TSHIRTS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_TIGHTS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_TRACKPANTS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_BRA_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_SHORTS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_TOPS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_TRACKSUITS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_JACKETS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
MP_WSA_SWEATSHIRTS_REVENUE = round((TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)
LY_TEMP_MP_WSA = LY_data[ (LY_data['master_brand'] == brand) & (LY_data['po_type'] == 'MP') & (LY_data['business_unit'] == "Women's Sports Apparel") ]
LY_MP_WSA_TSHIRTS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_TIGHTS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_TRACKPANTS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_BRA_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_SHORTS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_TOPS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_TRACKSUITS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_JACKETS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ]['revenue'].sum() / 10000000 ),4)
LY_MP_WSA_SWEATSHIRTS_REVENUE = round((LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ]['revenue'].sum() / 10000000 ),4)


#GM PERCENTAGE

PLATFORM_TOTAL_GM_PERCENTAGE = computeGM_Percentage(data)
MMB_GM_PERCENTAGE = computeGM_Percentage( data[data['brand_type'] == 'External'] )
MFB_GM_PERCENTAGE = computeGM_Percentage( data[data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_GM_PERCENTAGE = computeGM_Percentage( LY_data )
LY_MMB_GM_PERCENTAGE = computeGM_Percentage( LY_data[LY_data['brand_type'] == 'External'] )
LY_MFB_GM_PERCENTAGE = computeGM_Percentage( LY_data[LY_data['brand_type'] == 'Private'] )

MSA_GM_PERCENTAGE = computeGM_Percentage( data[data['business_unit'] == "Men's Sports Apparel"] )
WSA_GM_PERCENTAGE = computeGM_Percentage( data[data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_GM_PERCENTAGE = computeGM_Percentage( data[ (data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_GM_PERCENTAGE = computeGM_Percentage( LY_data[LY_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_GM_PERCENTAGE = computeGM_Percentage( LY_data[LY_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_GM_PERCENTAGE = computeGM_Percentage( LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_GM_PERCENTAGE = computeGM_Percentage( data[ (data['master_brand'] == brand)  ] )
HRX_OR_GM_PERCENTAGE = computeGM_Percentage( data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ] )
HRX_MP_GM_PERCENTAGE = computeGM_Percentage(data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ])
HRX_MSA_GM_PERCENTAGE = computeGM_Percentage(data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ])
HRX_WSA_GM_PERCENTAGE = computeGM_Percentage( data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_GM_PERCENTAGE = computeGM_Percentage( data[ ((data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel"))
                                                        & (data['master_brand'] == brand) ] )
LY_HRX_TOTAL_GM_PERCENTAGE = computeGM_Percentage( LY_data[ (LY_data['master_brand'] == brand)  ] )
LY_HRX_OR_GM_PERCENTAGE = computeGM_Percentage( LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ] )
LY_HRX_MP_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ])
LY_HRX_MSA_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_WSA_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_GM_PERCENTAGE = computeGM_Percentage( LY_data[ ((LY_data['business_unit'] == "Women's Sports Apparel") | (LY_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_data['master_brand'] == brand) ] )

#21 to 22
HRX_MSA_OR_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_MSA_MP_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_MSA_OR_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_MSA_MP_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ])    
#26 to 27
HRX_WSA_OR_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_WSA_MP_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_WSA_OR_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_WSA_MP_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ])


#31 TO 37
HRX_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])


OR_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ])
OR_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ])
OR_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ])
OR_MSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ])
OR_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
OR_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ])
OR_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])
LY_OR_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ])
LY_OR_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ])
LY_OR_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ])
LY_OR_MSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ])
LY_OR_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
LY_OR_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ])
LY_OR_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])

OR_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ])
OR_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ])
OR_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ])
OR_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ])
OR_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ])
OR_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ])
OR_WSA_TROUSERS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ])
OR_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
OR_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
OR_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])
LY_OR_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ])
LY_OR_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ])
LY_OR_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ])
LY_OR_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ])
LY_OR_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ])
LY_OR_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ])
LY_OR_WSA_TROUSERS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ])
LY_OR_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
LY_OR_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
LY_OR_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])

MP_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ])
MP_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ])
MP_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ])
MP_MSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ])
MP_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
MP_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ])
MP_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])
LY_MP_MSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ])
LY_MP_MSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ])
LY_MP_MSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ])
LY_MP_MSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ])
LY_MP_MSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
LY_MP_MSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ])
LY_MP_MSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])

MP_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ])
MP_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ])
MP_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ])
MP_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ])
MP_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ])
MP_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ])
MP_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
MP_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ])
MP_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])
LY_MP_WSA_TSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ])
LY_MP_WSA_TIGHTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ])
LY_MP_WSA_TRACKPANTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ])
LY_MP_WSA_BRA_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ])
LY_MP_WSA_SHORTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ])
LY_MP_WSA_TOPS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ])
LY_MP_WSA_TRACKSUITS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
LY_MP_WSA_JACKETS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ])
LY_MP_WSA_SWEATSHIRTS_GM_PERCENTAGE = computeGM_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])

#DISCOUNT

PLATFORM_TOTAL_TD_PERCENTAGE = computeTD_Percentage(data)
MMB_TD_PERCENTAGE = computeTD_Percentage( data[data['brand_type'] == 'External'] )
MFB_TD_PERCENTAGE = computeTD_Percentage( data[data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_TD_PERCENTAGE = computeTD_Percentage( LY_data )
LY_MMB_TD_PERCENTAGE = computeTD_Percentage( LY_data[LY_data['brand_type'] == 'External'] )
LY_MFB_TD_PERCENTAGE = computeTD_Percentage( LY_data[LY_data['brand_type'] == 'Private'] )

MSA_TD_PERCENTAGE = computeTD_Percentage( data[data['business_unit'] == "Men's Sports Apparel"] )
WSA_TD_PERCENTAGE = computeTD_Percentage( data[data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_TD_PERCENTAGE = computeTD_Percentage( data[ (data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_TD_PERCENTAGE = computeTD_Percentage( LY_data[LY_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_TD_PERCENTAGE = computeTD_Percentage( LY_data[LY_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_TD_PERCENTAGE = computeTD_Percentage( LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_TD_PERCENTAGE = computeTD_Percentage( data[ (data['master_brand'] == brand)  ] )
HRX_OR_TD_PERCENTAGE = computeTD_Percentage( data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ] )
HRX_MP_TD_PERCENTAGE = computeTD_Percentage(data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ])
HRX_MSA_TD_PERCENTAGE = computeTD_Percentage(data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ])
HRX_WSA_TD_PERCENTAGE = computeTD_Percentage( data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_TD_PERCENTAGE = computeTD_Percentage( data[ ((data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel"))
                                                        & (data['master_brand'] == brand) ] )
LY_HRX_TOTAL_TD_PERCENTAGE = computeTD_Percentage( LY_data[ (LY_data['master_brand'] == brand)  ] )
LY_HRX_OR_TD_PERCENTAGE = computeTD_Percentage( LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ] )
LY_HRX_MP_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ])
LY_HRX_MSA_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_WSA_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_TD_PERCENTAGE = computeTD_Percentage( LY_data[ ((LY_data['business_unit'] == "Women's Sports Apparel") | (LY_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_data['master_brand'] == brand) ] )

#21 to 22
HRX_MSA_OR_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_MSA_MP_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_MSA_OR_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_MSA_MP_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ])    
#26 to 27
HRX_WSA_OR_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_WSA_MP_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_WSA_OR_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_WSA_MP_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ])


#31 TO 37
HRX_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])


OR_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ])
OR_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ])
OR_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ])
OR_MSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ])
OR_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
OR_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ])
OR_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])
LY_OR_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ])
LY_OR_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ])
LY_OR_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ])
LY_OR_MSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ])
LY_OR_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
LY_OR_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ])
LY_OR_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])

OR_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ])
OR_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ])
OR_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ])
OR_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ])
OR_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ])
OR_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ])
OR_WSA_TROUSERS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ])
OR_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
OR_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
OR_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])
LY_OR_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ])
LY_OR_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ])
LY_OR_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ])
LY_OR_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ])
LY_OR_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ])
LY_OR_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ])
LY_OR_WSA_TROUSERS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ])
LY_OR_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
LY_OR_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
LY_OR_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])

MP_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ])
MP_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ])
MP_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ])
MP_MSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ])
MP_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
MP_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ])
MP_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])
LY_MP_MSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ])
LY_MP_MSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ])
LY_MP_MSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ])
LY_MP_MSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ])
LY_MP_MSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
LY_MP_MSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ])
LY_MP_MSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])

MP_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ])
MP_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ])
MP_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ])
MP_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ])
MP_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ])
MP_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ])
MP_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
MP_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ])
MP_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])
LY_MP_WSA_TSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ])
LY_MP_WSA_TIGHTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ])
LY_MP_WSA_TRACKPANTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ])
LY_MP_WSA_BRA_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ])
LY_MP_WSA_SHORTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ])
LY_MP_WSA_TOPS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ])
LY_MP_WSA_TRACKSUITS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
LY_MP_WSA_JACKETS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ])
LY_MP_WSA_SWEATSHIRTS_TD_PERCENTAGE = computeTD_Percentage(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])


#QTY

PLATFORM_TOTAL_QTY = Quantity_Sold(data)
MMB_QTY = Quantity_Sold( data[data['brand_type'] == 'External'] )
MFB_QTY = Quantity_Sold( data[data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_QTY = Quantity_Sold( LY_data )
LY_MMB_QTY = Quantity_Sold( LY_data[LY_data['brand_type'] == 'External'] )
LY_MFB_QTY = Quantity_Sold( LY_data[LY_data['brand_type'] == 'Private'] )

MSA_QTY = Quantity_Sold( data[data['business_unit'] == "Men's Sports Apparel"] )
WSA_QTY = Quantity_Sold( data[data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_QTY = Quantity_Sold( data[ (data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_QTY = Quantity_Sold( LY_data[LY_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_QTY = Quantity_Sold( LY_data[LY_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_QTY = Quantity_Sold( LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_QTY = Quantity_Sold( data[ (data['master_brand'] == brand)  ] )
HRX_OR_QTY = Quantity_Sold( data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ] )
HRX_MP_QTY = Quantity_Sold(data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ])
HRX_MSA_QTY = Quantity_Sold(data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ])
HRX_WSA_QTY = Quantity_Sold( data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_QTY = Quantity_Sold( data[ ((data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel"))
                                                        & (data['master_brand'] == brand) ] )
LY_HRX_TOTAL_QTY = Quantity_Sold( LY_data[ (LY_data['master_brand'] == brand)  ] )
LY_HRX_OR_QTY = Quantity_Sold( LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ] )
LY_HRX_MP_QTY = Quantity_Sold(LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ])
LY_HRX_MSA_QTY = Quantity_Sold(LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_WSA_QTY = Quantity_Sold(LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_QTY = Quantity_Sold( LY_data[ ((LY_data['business_unit'] == "Women's Sports Apparel") | (LY_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_data['master_brand'] == brand) ] )

#21 to 22
HRX_MSA_OR_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_MSA_MP_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_MSA_OR_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_MSA_MP_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ])    
#26 to 27
HRX_WSA_OR_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_WSA_MP_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_WSA_OR_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_WSA_MP_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ])


#31 TO 37
HRX_MSA_TSHIRTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_QTY = Quantity_Sold(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])


OR_MSA_TSHIRTS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ])
OR_MSA_TRACKPANTS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ])
OR_MSA_SHORTS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ])
OR_MSA_TIGHTS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ])
OR_MSA_TRACKSUITS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
OR_MSA_JACKETS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ])
OR_MSA_SWEATSHIRTS_QTY = Quantity_Sold(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])
LY_OR_MSA_TSHIRTS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ])
LY_OR_MSA_TRACKPANTS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ])
LY_OR_MSA_SHORTS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ])
LY_OR_MSA_TIGHTS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ])
LY_OR_MSA_TRACKSUITS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
LY_OR_MSA_JACKETS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ])
LY_OR_MSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])

OR_WSA_TSHIRTS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ])
OR_WSA_TIGHTS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ])
OR_WSA_TRACKPANTS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ])
OR_WSA_BRA_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ])
OR_WSA_SHORTS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ])
OR_WSA_TOPS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ])
OR_WSA_TROUSERS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ])
OR_WSA_TRACKSUITS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
OR_WSA_JACKETS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
OR_WSA_SWEATSHIRTS_QTY = Quantity_Sold(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])
LY_OR_WSA_TSHIRTS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ])
LY_OR_WSA_TIGHTS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ])
LY_OR_WSA_TRACKPANTS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ])
LY_OR_WSA_BRA_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ])
LY_OR_WSA_SHORTS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ])
LY_OR_WSA_TOPS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ])
LY_OR_WSA_TROUSERS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ])
LY_OR_WSA_TRACKSUITS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
LY_OR_WSA_JACKETS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
LY_OR_WSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])

MP_MSA_TSHIRTS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ])
MP_MSA_TRACKPANTS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ])
MP_MSA_SHORTS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ])
MP_MSA_TIGHTS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ])
MP_MSA_TRACKSUITS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
MP_MSA_JACKETS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ])
MP_MSA_SWEATSHIRTS_QTY = Quantity_Sold(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])
LY_MP_MSA_TSHIRTS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ])
LY_MP_MSA_TRACKPANTS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ])
LY_MP_MSA_SHORTS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ])
LY_MP_MSA_TIGHTS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ])
LY_MP_MSA_TRACKSUITS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
LY_MP_MSA_JACKETS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ])
LY_MP_MSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])

MP_WSA_TSHIRTS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ])
MP_WSA_TIGHTS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ])
MP_WSA_TRACKPANTS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ])
MP_WSA_BRA_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ])
MP_WSA_SHORTS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ])
MP_WSA_TOPS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ])
MP_WSA_TRACKSUITS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
MP_WSA_JACKETS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ])
MP_WSA_SWEATSHIRTS_QTY = Quantity_Sold(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])
LY_MP_WSA_TSHIRTS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ])
LY_MP_WSA_TIGHTS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ])
LY_MP_WSA_TRACKPANTS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ])
LY_MP_WSA_BRA_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ])
LY_MP_WSA_SHORTS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ])
LY_MP_WSA_TOPS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ])
LY_MP_WSA_TRACKSUITS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
LY_MP_WSA_JACKETS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ])
LY_MP_WSA_SWEATSHIRTS_QTY = Quantity_Sold(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])




def compute_Average_MRP(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        tmrp = dump['tot_mrp'].sum()
        tqty = dump['quantity'].sum()
        result = round((tmrp / tqty))
        return result

PLATFORM_TOTAL_AVG_MRP = compute_Average_MRP(data)
MMB_AVG_MRP = compute_Average_MRP( data[data['brand_type'] == 'External'] )
MFB_AVG_MRP = compute_Average_MRP( data[data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_AVG_MRP = compute_Average_MRP( LY_data )
LY_MMB_AVG_MRP = compute_Average_MRP( LY_data[LY_data['brand_type'] == 'External'] )
LY_MFB_AVG_MRP = compute_Average_MRP( LY_data[LY_data['brand_type'] == 'Private'] )

MSA_AVG_MRP = compute_Average_MRP( data[data['business_unit'] == "Men's Sports Apparel"] )
WSA_AVG_MRP = compute_Average_MRP( data[data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_AVG_MRP = compute_Average_MRP( data[ (data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_AVG_MRP = compute_Average_MRP( LY_data[LY_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_AVG_MRP = compute_Average_MRP( LY_data[LY_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_AVG_MRP = compute_Average_MRP( LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_AVG_MRP = compute_Average_MRP( data[ (data['master_brand'] == brand)  ] )
HRX_OR_AVG_MRP = compute_Average_MRP( data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ] )
HRX_MP_AVG_MRP = compute_Average_MRP(data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ])
HRX_MSA_AVG_MRP = compute_Average_MRP(data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ])
HRX_WSA_AVG_MRP = compute_Average_MRP( data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_AVG_MRP = compute_Average_MRP( data[ ((data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel"))
                                                        & (data['master_brand'] == brand) ] )
LY_HRX_TOTAL_AVG_MRP = compute_Average_MRP( LY_data[ (LY_data['master_brand'] == brand)  ] )
LY_HRX_OR_AVG_MRP = compute_Average_MRP( LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ] )
LY_HRX_MP_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ])
LY_HRX_MSA_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_WSA_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_AVG_MRP = compute_Average_MRP( LY_data[ ((LY_data['business_unit'] == "Women's Sports Apparel") | (LY_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_data['master_brand'] == brand) ] )

#21 to 22
HRX_MSA_OR_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_MSA_MP_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_MSA_OR_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_MSA_MP_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ])    
#26 to 27
HRX_WSA_OR_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_WSA_MP_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_WSA_OR_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_WSA_MP_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ])


#31 TO 37
HRX_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])


OR_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ])
OR_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ])
OR_MSA_SHORTS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ])
OR_MSA_TIGHTS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ])
OR_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
OR_MSA_JACKETS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ])
OR_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])
LY_OR_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ])
LY_OR_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ])
LY_OR_MSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ])
LY_OR_MSA_TIGHTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ])
LY_OR_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
LY_OR_MSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ])
LY_OR_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])

OR_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ])
OR_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ])
OR_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ])
OR_WSA_BRA_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ])
OR_WSA_SHORTS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ])
OR_WSA_TOPS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ])
OR_WSA_TROUSERS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ])
OR_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
OR_WSA_JACKETS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
OR_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])
LY_OR_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ])
LY_OR_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ])
LY_OR_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ])
LY_OR_WSA_BRA_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ])
LY_OR_WSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ])
LY_OR_WSA_TOPS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ])
LY_OR_WSA_TROUSERS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ])
LY_OR_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
LY_OR_WSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
LY_OR_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])

MP_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ])
MP_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ])
MP_MSA_SHORTS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ])
MP_MSA_TIGHTS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ])
MP_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
MP_MSA_JACKETS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ])
MP_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])
LY_MP_MSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ])
LY_MP_MSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ])
LY_MP_MSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ])
LY_MP_MSA_TIGHTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ])
LY_MP_MSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
LY_MP_MSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ])
LY_MP_MSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])

MP_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ])
MP_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ])
MP_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ])
MP_WSA_BRA_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ])
MP_WSA_SHORTS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ])
MP_WSA_TOPS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ])
MP_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
MP_WSA_JACKETS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ])
MP_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])
LY_MP_WSA_TSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ])
LY_MP_WSA_TIGHTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ])
LY_MP_WSA_TRACKPANTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ])
LY_MP_WSA_BRA_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ])
LY_MP_WSA_SHORTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ])
LY_MP_WSA_TOPS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ])
LY_MP_WSA_TRACKSUITS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
LY_MP_WSA_JACKETS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ])
LY_MP_WSA_SWEATSHIRTS_AVG_MRP = compute_Average_MRP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])



def compute_Average_ISP(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        trev = dump['revenue'].sum()
        tqty = dump['quantity'].sum()
        result = round((trev / tqty))
        return result

PLATFORM_TOTAL_AVG_ISP = compute_Average_ISP(data)
MMB_AVG_ISP = compute_Average_ISP( data[data['brand_type'] == 'External'] )
MFB_AVG_ISP = compute_Average_ISP( data[data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_AVG_ISP = compute_Average_ISP( LY_data )
LY_MMB_AVG_ISP = compute_Average_ISP( LY_data[LY_data['brand_type'] == 'External'] )
LY_MFB_AVG_ISP = compute_Average_ISP( LY_data[LY_data['brand_type'] == 'Private'] )

MSA_AVG_ISP = compute_Average_ISP( data[data['business_unit'] == "Men's Sports Apparel"] )
WSA_AVG_ISP = compute_Average_ISP( data[data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_AVG_ISP = compute_Average_ISP( data[ (data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_AVG_ISP = compute_Average_ISP( LY_data[LY_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_AVG_ISP = compute_Average_ISP( LY_data[LY_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_AVG_ISP = compute_Average_ISP( LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_AVG_ISP = compute_Average_ISP( data[ (data['master_brand'] == brand) ] )
HRX_OR_AVG_ISP = compute_Average_ISP( data[ (data['po_type'] == 'OR') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ] )
HRX_MP_AVG_ISP = compute_Average_ISP(data[ (data['po_type'] == 'MP') & (data['master_brand'] == brand) & ((data['business_unit'] == "Men's Sports Apparel" ) | (data['business_unit'] == "Women's Sports Apparel" )) ])
HRX_MSA_AVG_ISP = compute_Average_ISP(data[ (data['business_unit'] == "Men's Sports Apparel") & (data['master_brand'] == brand) ])
HRX_WSA_AVG_ISP = compute_Average_ISP( data[ (data['business_unit'] == "Women's Sports Apparel") & (data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_AVG_ISP = compute_Average_ISP( data[ ((data['business_unit'] == "Women's Sports Apparel") | (data['business_unit'] == "Men's Sports Apparel"))
                                                        & (data['master_brand'] == brand) ] )
LY_HRX_TOTAL_AVG_ISP = compute_Average_ISP( LY_data[ (LY_data['master_brand'] == brand)  ] )
LY_HRX_OR_AVG_ISP = compute_Average_ISP( LY_data[ (LY_data['po_type'] == 'OR') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ] )
LY_HRX_MP_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['po_type'] == 'MP') & (LY_data['master_brand'] == brand) & ((LY_data['business_unit'] == "Men's Sports Apparel" ) | (LY_data['business_unit'] == "Women's Sports Apparel" )) ])
LY_HRX_MSA_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_WSA_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_AVG_ISP = compute_Average_ISP( LY_data[ ((LY_data['business_unit'] == "Women's Sports Apparel") | (LY_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_data['master_brand'] == brand) ] )

#21 to 22
HRX_MSA_OR_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_MSA_MP_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_MSA_OR_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_MSA_MP_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['po_type'] == 'MP') ])    
#26 to 27
HRX_WSA_OR_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'OR') ])    
HRX_WSA_MP_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['po_type'] == 'MP') ])    
LY_HRX_WSA_OR_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'OR') ])    
LY_HRX_WSA_MP_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['po_type'] == 'MP') ])


#31 TO 37
HRX_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                    (data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & 
                                 (data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Men's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Men's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(data[ (data['master_brand'] == brand) & (data['business_unit'] == "Women's Sports Apparel") & (data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_data[ (LY_data['master_brand'] == brand) & (LY_data['business_unit'] == "Women's Sports Apparel") & (LY_data['article_type'] == 'Sweatshirts') ])


OR_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tshirts' ])
OR_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Track Pants' ])
OR_MSA_SHORTS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Shorts' ])
OR_MSA_TIGHTS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tights' ])
OR_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
OR_MSA_JACKETS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Jackets' ])
OR_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_OR_MSA[ TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])
LY_OR_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tshirts' ])
LY_OR_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Track Pants' ])
LY_OR_MSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Shorts' ])
LY_OR_MSA_TIGHTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tights' ])
LY_OR_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Tracksuits' ])
LY_OR_MSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Jackets' ])
LY_OR_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_MSA[ LY_TEMP_OR_MSA['article_type'] == 'Sweatshirts' ])

OR_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tshirts' ])
OR_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tights' ])
OR_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Track Pants' ])
OR_WSA_BRA_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Bra' ])
OR_WSA_SHORTS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Shorts' ])
OR_WSA_TOPS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tops' ])
OR_WSA_TROUSERS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Trousers' ])
OR_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
OR_WSA_JACKETS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Jackets' ]) #$
OR_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_OR_WSA[ TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])
LY_OR_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tshirts' ])
LY_OR_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tights' ])
LY_OR_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Track Pants' ])
LY_OR_WSA_BRA_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Bra' ])
LY_OR_WSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Shorts' ])
LY_OR_WSA_TOPS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tops' ])
LY_OR_WSA_TROUSERS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Trousers' ])
LY_OR_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Tracksuits' ])
LY_OR_WSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Jackets' ])#$
LY_OR_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_OR_WSA[ LY_TEMP_OR_WSA['article_type'] == 'Sweatshirts' ])

MP_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tshirts' ])
MP_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Track Pants' ])
MP_MSA_SHORTS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Shorts' ])
MP_MSA_TIGHTS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tights' ])
MP_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
MP_MSA_JACKETS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Jackets' ])
MP_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_MP_MSA[ TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])
LY_MP_MSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tshirts' ])
LY_MP_MSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Track Pants' ])
LY_MP_MSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Shorts' ])
LY_MP_MSA_TIGHTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tights' ])
LY_MP_MSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Tracksuits' ])
LY_MP_MSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Jackets' ])
LY_MP_MSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_MSA[ LY_TEMP_MP_MSA['article_type'] == 'Sweatshirts' ])

MP_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tshirts' ])
MP_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tights' ])
MP_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Track Pants' ])
MP_WSA_BRA_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Bra' ])
MP_WSA_SHORTS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Shorts' ])
MP_WSA_TOPS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tops' ])
MP_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
MP_WSA_JACKETS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Jackets' ])
MP_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(TEMP_MP_WSA[ TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])
LY_MP_WSA_TSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tshirts' ])
LY_MP_WSA_TIGHTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tights' ])
LY_MP_WSA_TRACKPANTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Track Pants' ])
LY_MP_WSA_BRA_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Bra' ])
LY_MP_WSA_SHORTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Shorts' ])
LY_MP_WSA_TOPS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tops' ])
LY_MP_WSA_TRACKSUITS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Tracksuits' ])
LY_MP_WSA_JACKETS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Jackets' ])
LY_MP_WSA_SWEATSHIRTS_AVG_ISP = compute_Average_ISP(LY_TEMP_MP_WSA[ LY_TEMP_MP_WSA['article_type'] == 'Sweatshirts' ])



def compute_List_Count(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        lc = round(((dump['list_view'].sum()) / 10000000),2)
        return lc

PLATFORM_TOTAL_LC    = compute_List_Count(v_data)
MMB_LC               = compute_List_Count( v_data[v_data['brand_type'] == 'External'] )
MFB_LC               = compute_List_Count( v_data[v_data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_LC = compute_List_Count( LY_v_data )
LY_MMB_LC            = compute_List_Count( LY_v_data[LY_v_data['brand_type'] == 'External'] )
LY_MFB_LC            = compute_List_Count( LY_v_data[LY_v_data['brand_type'] == 'Private'] )

MSA_LC               = compute_List_Count( v_data[v_data['business_unit'] == "Men's Sports Apparel"] )
WSA_LC               = compute_List_Count( v_data[v_data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_LC       = compute_List_Count( v_data[ (v_data['business_unit'] == "Women's Sports Apparel") | (v_data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_LC            = compute_List_Count( LY_v_data[LY_v_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_LC            = compute_List_Count( LY_v_data[LY_v_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_LC    = compute_List_Count( LY_v_data[ (LY_v_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_v_data['business_unit'] == "Men's Sports Apparel") ] )

#13 to 18
HRX_TOTAL_LC          = compute_List_Count( v_data[ (v_data['master_brand'] == brand)  ] )
HRX_MSA_LC            = compute_List_Count(v_data[ (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['master_brand'] == brand) ])
HRX_WSA_LC            = compute_List_Count( v_data[ (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_LC = compute_List_Count( v_data[ ((v_data['business_unit'] == "Women's Sports Apparel") | (v_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (v_data['master_brand'] == brand) ] )
LY_HRX_TOTAL_LC       = compute_List_Count( LY_v_data[ (LY_v_data['master_brand'] == brand)  ] )
LY_HRX_MSA_LC         = compute_List_Count(LY_v_data[ (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['master_brand'] == brand) ])
LY_HRX_WSA_LC = compute_List_Count(LY_v_data[ (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_LC = compute_List_Count( LY_v_data[ ((LY_v_data['business_unit'] == "Women's Sports Apparel") | (LY_v_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_v_data['master_brand'] == brand) ] )


#31 TO 37
HRX_MSA_TSHIRTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & 
                                    (v_data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & 
                                 (v_data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_v_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_v_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Sweatshirts') ])

#40 to 49
HRX_WSA_TSHIRTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_LC = compute_List_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_LC = compute_List_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Sweatshirts') ])



def compute_PDP_Count(dump):
    if len(dump) == 0:
        return 'NA'
    else:
        pdp = round(((dump['pdp_count'].sum()) / 10000000),2)
        return pdp

        
PLATFORM_TOTAL_PDP = compute_PDP_Count(v_data)
MMB_PDP = compute_PDP_Count( v_data[v_data['brand_type'] == 'External'] )
MFB_PDP = compute_PDP_Count( v_data[v_data['brand_type'] == 'Private'] )
LY_PLATFORM_TOTAL_PDP = compute_PDP_Count( LY_v_data )
LY_MMB_PDP = compute_PDP_Count( LY_v_data[LY_v_data['brand_type'] == 'External'] )
LY_MFB_PDP = compute_PDP_Count( LY_v_data[LY_v_data['brand_type'] == 'Private'] )

MSA_PDP = compute_PDP_Count( v_data[v_data['business_unit'] == "Men's Sports Apparel"] )
WSA_PDP = compute_PDP_Count( v_data[v_data['business_unit'] == "Women's Sports Apparel"] )
SPORTS_WEAR_PDP = compute_PDP_Count( v_data[ (v_data['business_unit'] == "Women's Sports Apparel") | (v_data['business_unit'] == "Men's Sports Apparel") ] )
LY_MSA_PDP = compute_PDP_Count( LY_v_data[LY_v_data['business_unit'] == "Men's Sports Apparel"] )
LY_WSA_PDP = compute_PDP_Count( LY_v_data[LY_v_data['business_unit'] == "Women's Sports Apparel"] )
LY_SPORTS_WEAR_PDP = compute_PDP_Count( LY_v_data[ (LY_v_data['business_unit'] == "Women's Sports Apparel") | 
                                                    (LY_v_data['business_unit'] == "Men's Sports Apparel") ] )

HRX_TOTAL_PDP = compute_PDP_Count( v_data[ (v_data['master_brand'] == brand)  ] )
HRX_MSA_PDP = compute_PDP_Count(v_data[ (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['master_brand'] == brand) ])
HRX_WSA_PDP = compute_PDP_Count( v_data[ (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['master_brand'] == brand) ] )
HRX_M_PLUS_W_TOTAL_PDP = compute_PDP_Count( v_data[ ((v_data['business_unit'] == "Women's Sports Apparel") | (v_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (v_data['master_brand'] == brand) ] )
LY_HRX_TOTAL_PDP = compute_PDP_Count( LY_v_data[ (LY_v_data['master_brand'] == brand)  ] )
LY_HRX_MSA_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['master_brand'] == brand) ])
LY_HRX_WSA_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['master_brand'] == brand) ])
LY_HRX_M_PLUS_W_TOTAL_PDP = compute_PDP_Count( LY_v_data[ ((LY_v_data['business_unit'] == "Women's Sports Apparel") | (LY_v_data['business_unit'] == "Men's Sports Apparel"))
                                                        & (LY_v_data['master_brand'] == brand) ] )

HRX_MSA_TSHIRTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Tshirts') ])
HRX_MSA_TRACKPANTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Track Pants') ])
HRX_MSA_SHORTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Shorts') ])
HRX_MSA_COORDS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Co-Ords') ])
HRX_MSA_TRACKSUITS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & 
                                    (v_data['article_type'] == 'Tracksuits') ])
HRX_MSA_JACKETS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & 
                                 (v_data['article_type'] == 'Jackets') ])
HRX_MSA_SWEATSHIRTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Men's Sports Apparel") & (v_data['article_type'] == 'Sweatshirts') ])
LY_HRX_MSA_TSHIRTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Tshirts') ])
LY_HRX_MSA_TRACKPANTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Track Pants') ])
LY_HRX_MSA_SHORTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Shorts') ])
LY_HRX_MSA_COORDS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Co-Ords') ])
LY_HRX_MSA_TRACKSUITS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & 
                                    (LY_v_data['article_type'] == 'Tracksuits') ])
LY_HRX_MSA_JACKETS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & 
                                 (LY_v_data['article_type'] == 'Jackets') ])
LY_HRX_MSA_SWEATSHIRTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Men's Sports Apparel") & (LY_v_data['article_type'] == 'Sweatshirts') ])

HRX_WSA_TSHIRTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tshirts') ])
HRX_WSA_TIGHTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tights') ])
HRX_WSA_TRACKPANTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Track Pants') ])
HRX_WSA_BRA_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Bra') ])
HRX_WSA_SHORTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Shorts') ])
HRX_WSA_TOPS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tops') ])
HRX_WSA_TROUSERS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Trousers') ])
HRX_WSA_TRACKSUITS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Tracksuits') ])
HRX_WSA_JACKETS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Jackets') ])
HRX_WSA_SWEATSHIRTS_PDP = compute_PDP_Count(v_data[ (v_data['master_brand'] == brand) & (v_data['business_unit'] == "Women's Sports Apparel") & (v_data['article_type'] == 'Sweatshirts') ])
LY_HRX_WSA_TSHIRTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tshirts') ])
LY_HRX_WSA_TIGHTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tights') ])
LY_HRX_WSA_TRACKPANTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Track Pants') ])
LY_HRX_WSA_BRA_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Bra') ])
LY_HRX_WSA_SHORTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Shorts') ])
LY_HRX_WSA_TOPS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tops') ])
LY_HRX_WSA_TROUSERS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Trousers') ])
LY_HRX_WSA_TRACKSUITS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Tracksuits') ])
LY_HRX_WSA_JACKETS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Jackets') ])
LY_HRX_WSA_SWEATSHIRTS_PDP = compute_PDP_Count(LY_v_data[ (LY_v_data['master_brand'] == brand) & (LY_v_data['business_unit'] == "Women's Sports Apparel") & (LY_v_data['article_type'] == 'Sweatshirts') ])


metrics = [
    [PLATFORM_TOTAL_REVENUE,LY_PLATFORM_TOTAL_REVENUE,PLATFORM_TOTAL_GM_PERCENTAGE,LY_PLATFORM_TOTAL_GM_PERCENTAGE,PLATFORM_TOTAL_TD_PERCENTAGE,
LY_PLATFORM_TOTAL_TD_PERCENTAGE,PLATFORM_TOTAL_QTY,LY_PLATFORM_TOTAL_QTY,PLATFORM_TOTAL_AVG_MRP,LY_PLATFORM_TOTAL_AVG_MRP,PLATFORM_TOTAL_AVG_ISP,
LY_PLATFORM_TOTAL_AVG_ISP,PLATFORM_TOTAL_LC ,LY_PLATFORM_TOTAL_LC ,PLATFORM_TOTAL_PDP ,LY_PLATFORM_TOTAL_PDP ],
    [MMB_REVENUE,LY_MMB_REVENUE,MMB_GM_PERCENTAGE,LY_MMB_GM_PERCENTAGE,MMB_TD_PERCENTAGE
,LY_MMB_TD_PERCENTAGE,MMB_QTY,LY_MMB_QTY,MMB_AVG_MRP,LY_MMB_AVG_MRP,MMB_AVG_ISP,LY_MMB_AVG_ISP,MMB_LC ,LY_MMB_LC,MMB_PDP ,LY_MMB_PDP  ],
    [MFB_REVENUE,LY_MFB_REVENUE,MFB_GM_PERCENTAGE,LY_MFB_GM_PERCENTAGE,MFB_TD_PERCENTAGE
,LY_MFB_TD_PERCENTAGE,MFB_QTY,LY_MFB_QTY,MFB_AVG_MRP,LY_MFB_AVG_MRP,MFB_AVG_ISP,LY_MFB_AVG_ISP,MFB_LC ,LY_MFB_LC,MFB_PDP ,LY_MFB_PDP  ],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [SPORTS_WEAR_REVENUE,LY_SPORTS_WEAR_REVENUE,SPORTS_WEAR_GM_PERCENTAGE,LY_SPORTS_WEAR_GM_PERCENTAGE,SPORTS_WEAR_TD_PERCENTAGE
,LY_SPORTS_WEAR_TD_PERCENTAGE,SPORTS_WEAR_QTY,LY_SPORTS_WEAR_QTY,SPORTS_WEAR_AVG_MRP,LY_SPORTS_WEAR_AVG_MRP,SPORTS_WEAR_AVG_ISP,LY_SPORTS_WEAR_AVG_ISP,SPORTS_WEAR_LC 
,LY_SPORTS_WEAR_LC  ,SPORTS_WEAR_PDP ,LY_SPORTS_WEAR_PDP ],
    [MSA_REVENUE,LY_MSA_REVENUE,MSA_GM_PERCENTAGE,LY_MSA_GM_PERCENTAGE,MSA_TD_PERCENTAGE
,LY_MSA_TD_PERCENTAGE,MSA_QTY,LY_MSA_QTY,MSA_AVG_MRP,LY_MSA_AVG_MRP,MSA_AVG_ISP,LY_MSA_AVG_ISP,MSA_LC ,LY_MSA_LC ,MSA_PDP ,LY_MSA_PDP],
    [WSA_REVENUE,LY_WSA_REVENUE,WSA_GM_PERCENTAGE,LY_WSA_GM_PERCENTAGE,WSA_TD_PERCENTAGE
,LY_WSA_TD_PERCENTAGE,WSA_QTY,LY_WSA_QTY,WSA_AVG_MRP,LY_WSA_AVG_MRP,WSA_AVG_ISP,LY_WSA_AVG_ISP,WSA_LC ,LY_WSA_LC ,WSA_PDP ,LY_WSA_PDP ],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [HRX_TOTAL_REVENUE,LY_HRX_TOTAL_REVENUE,HRX_TOTAL_GM_PERCENTAGE,LY_HRX_TOTAL_GM_PERCENTAGE,HRX_TOTAL_TD_PERCENTAGE
,LY_HRX_TOTAL_TD_PERCENTAGE,HRX_TOTAL_QTY,LY_HRX_TOTAL_QTY,HRX_TOTAL_AVG_MRP,LY_HRX_TOTAL_AVG_MRP,HRX_TOTAL_AVG_ISP,LY_HRX_TOTAL_AVG_ISP,HRX_TOTAL_LC 
,LY_HRX_TOTAL_LC ,HRX_TOTAL_PDP ,LY_HRX_TOTAL_PDP ],
    [HRX_OR_REVENUE,LY_HRX_OR_REVENUE,HRX_OR_GM_PERCENTAGE,LY_HRX_OR_GM_PERCENTAGE,HRX_OR_TD_PERCENTAGE
,LY_HRX_OR_TD_PERCENTAGE,HRX_OR_QTY,LY_HRX_OR_QTY,HRX_OR_AVG_MRP,LY_HRX_OR_AVG_MRP,HRX_OR_AVG_ISP,LY_HRX_OR_AVG_ISP,'-','-','-','-'],
    [HRX_MP_REVENUE,LY_HRX_MP_REVENUE,HRX_MP_GM_PERCENTAGE,LY_HRX_MP_GM_PERCENTAGE,HRX_MP_TD_PERCENTAGE
,LY_HRX_MP_TD_PERCENTAGE,HRX_MP_QTY,LY_HRX_MP_QTY,HRX_MP_AVG_MRP,LY_HRX_MP_AVG_MRP,HRX_MP_AVG_ISP,LY_HRX_MP_AVG_ISP,'-','-','-','-'],
    [HRX_MSA_REVENUE,LY_HRX_MSA_REVENUE,HRX_MSA_GM_PERCENTAGE,LY_HRX_MSA_GM_PERCENTAGE,HRX_MSA_TD_PERCENTAGE
,LY_HRX_MSA_TD_PERCENTAGE,HRX_MSA_QTY,LY_HRX_MSA_QTY,HRX_MSA_AVG_MRP,LY_HRX_MSA_AVG_MRP,HRX_MSA_AVG_ISP,LY_HRX_MSA_AVG_ISP,HRX_MSA_LC ,LY_HRX_MSA_LC,HRX_MSA_PDP 
,LY_HRX_MSA_PDP  ],
    [HRX_WSA_REVENUE,LY_HRX_WSA_REVENUE,HRX_WSA_GM_PERCENTAGE,LY_HRX_WSA_GM_PERCENTAGE,HRX_WSA_TD_PERCENTAGE
,LY_HRX_WSA_TD_PERCENTAGE,HRX_WSA_QTY,LY_HRX_WSA_QTY,HRX_WSA_AVG_MRP,LY_HRX_WSA_AVG_MRP,HRX_WSA_AVG_ISP,LY_HRX_WSA_AVG_ISP,HRX_WSA_LC ,LY_HRX_WSA_LC,HRX_WSA_PDP 
,LY_HRX_WSA_PDP  ],
    [HRX_M_PLUS_W_TOTAL_REVENUE,LY_HRX_M_PLUS_W_TOTAL_REVENUE,HRX_M_PLUS_W_TOTAL_GM_PERCENTAGE,LY_HRX_M_PLUS_W_TOTAL_GM_PERCENTAGE,HRX_M_PLUS_W_TOTAL_TD_PERCENTAGE
,LY_HRX_M_PLUS_W_TOTAL_TD_PERCENTAGE,HRX_M_PLUS_W_TOTAL_QTY,LY_HRX_M_PLUS_W_TOTAL_QTY,HRX_M_PLUS_W_TOTAL_AVG_MRP,LY_HRX_M_PLUS_W_TOTAL_AVG_MRP,
HRX_M_PLUS_W_TOTAL_AVG_ISP,LY_HRX_M_PLUS_W_TOTAL_AVG_ISP,HRX_M_PLUS_W_TOTAL_LC ,LY_HRX_M_PLUS_W_TOTAL_LC ,HRX_M_PLUS_W_TOTAL_PDP ,LY_HRX_M_PLUS_W_TOTAL_PDP ],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [HRX_MSA_OR_REVENUE,LY_HRX_MSA_OR_REVENUE,HRX_MSA_OR_GM_PERCENTAGE,LY_HRX_MSA_OR_GM_PERCENTAGE,HRX_MSA_OR_TD_PERCENTAGE
,LY_HRX_MSA_OR_TD_PERCENTAGE,HRX_MSA_OR_QTY,LY_HRX_MSA_OR_QTY,HRX_MSA_OR_AVG_MRP,LY_HRX_MSA_OR_AVG_MRP,HRX_MSA_OR_AVG_ISP,LY_HRX_MSA_OR_AVG_ISP,'-','-','-','-'],
    [HRX_MSA_MP_REVENUE,LY_HRX_MSA_MP_REVENUE,HRX_MSA_MP_GM_PERCENTAGE,LY_HRX_MSA_MP_GM_PERCENTAGE,HRX_MSA_MP_TD_PERCENTAGE,
LY_HRX_MSA_MP_TD_PERCENTAGE,HRX_MSA_MP_QTY,LY_HRX_MSA_MP_QTY,HRX_MSA_MP_AVG_MRP,LY_HRX_MSA_MP_AVG_MRP,HRX_MSA_MP_AVG_ISP,LY_HRX_MSA_MP_AVG_ISP,'-','-','-','-'],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [HRX_WSA_OR_REVENUE,LY_HRX_WSA_OR_REVENUE,HRX_WSA_OR_GM_PERCENTAGE,LY_HRX_WSA_OR_GM_PERCENTAGE,HRX_WSA_OR_TD_PERCENTAGE
,LY_HRX_WSA_OR_TD_PERCENTAGE,HRX_WSA_OR_QTY,LY_HRX_WSA_OR_QTY,HRX_WSA_OR_AVG_MRP,LY_HRX_WSA_OR_AVG_MRP,HRX_WSA_OR_AVG_ISP,LY_HRX_WSA_OR_AVG_ISP,'-','-','-','-'],
    [HRX_WSA_MP_REVENUE,LY_HRX_WSA_MP_REVENUE,HRX_WSA_MP_GM_PERCENTAGE,LY_HRX_WSA_MP_GM_PERCENTAGE,HRX_WSA_MP_TD_PERCENTAGE
,LY_HRX_WSA_MP_TD_PERCENTAGE,HRX_WSA_MP_QTY,LY_HRX_WSA_MP_QTY,HRX_WSA_MP_AVG_MRP,LY_HRX_WSA_MP_AVG_MRP,HRX_WSA_MP_AVG_ISP,LY_HRX_WSA_MP_AVG_ISP,'-','-','-','-'],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [HRX_MSA_TSHIRTS_REVENUE,LY_HRX_MSA_TSHIRTS_REVENUE,HRX_MSA_TSHIRTS_GM_PERCENTAGE,LY_HRX_MSA_TSHIRTS_GM_PERCENTAGE,HRX_MSA_TSHIRTS_TD_PERCENTAGE
,LY_HRX_MSA_TSHIRTS_TD_PERCENTAGE,HRX_MSA_TSHIRTS_QTY,LY_HRX_MSA_TSHIRTS_QTY,HRX_MSA_TSHIRTS_AVG_MRP,LY_HRX_MSA_TSHIRTS_AVG_MRP,HRX_MSA_TSHIRTS_AVG_ISP
,LY_HRX_MSA_TSHIRTS_AVG_ISP,HRX_MSA_TSHIRTS_LC ,LY_HRX_MSA_TSHIRTS_LC ,HRX_MSA_TSHIRTS_PDP ,LY_HRX_MSA_TSHIRTS_PDP ],
    [HRX_MSA_TRACKPANTS_REVENUE,LY_HRX_MSA_TRACKPANTS_REVENUE,HRX_MSA_TRACKPANTS_GM_PERCENTAGE,LY_HRX_MSA_TRACKPANTS_GM_PERCENTAGE,HRX_MSA_TRACKPANTS_TD_PERCENTAGE
,LY_HRX_MSA_TRACKPANTS_TD_PERCENTAGE,HRX_MSA_TRACKPANTS_QTY,LY_HRX_MSA_TRACKPANTS_QTY,HRX_MSA_TRACKPANTS_AVG_MRP,LY_HRX_MSA_TRACKPANTS_AVG_MRP,HRX_MSA_TRACKPANTS_AVG_ISP
,LY_HRX_MSA_TRACKPANTS_AVG_ISP,HRX_MSA_TRACKPANTS_LC ,LY_HRX_MSA_TRACKPANTS_LC ,HRX_MSA_TRACKPANTS_PDP ,LY_HRX_MSA_TRACKPANTS_PDP ],
    [HRX_MSA_SHORTS_REVENUE,LY_HRX_MSA_SHORTS_REVENUE,HRX_MSA_SHORTS_GM_PERCENTAGE,LY_HRX_MSA_SHORTS_GM_PERCENTAGE,HRX_MSA_SHORTS_TD_PERCENTAGE
,LY_HRX_MSA_SHORTS_TD_PERCENTAGE,HRX_MSA_SHORTS_QTY,LY_HRX_MSA_SHORTS_QTY,HRX_MSA_SHORTS_AVG_MRP,LY_HRX_MSA_SHORTS_AVG_MRP,HRX_MSA_SHORTS_AVG_ISP,LY_HRX_MSA_SHORTS_AVG_ISP,
HRX_MSA_SHORTS_LC ,LY_HRX_MSA_SHORTS_LC ,HRX_MSA_SHORTS_PDP ,LY_HRX_MSA_SHORTS_PDP ],
    [HRX_MSA_COORDS_REVENUE,LY_HRX_MSA_COORDS_REVENUE,HRX_MSA_COORDS_GM_PERCENTAGE,LY_HRX_MSA_COORDS_GM_PERCENTAGE,HRX_MSA_COORDS_TD_PERCENTAGE
,LY_HRX_MSA_COORDS_TD_PERCENTAGE,HRX_MSA_COORDS_QTY,LY_HRX_MSA_COORDS_QTY,HRX_MSA_COORDS_AVG_MRP,LY_HRX_MSA_COORDS_AVG_MRP,HRX_MSA_COORDS_AVG_ISP
,LY_HRX_MSA_COORDS_AVG_ISP,HRX_MSA_COORDS_LC ,LY_HRX_MSA_COORDS_LC ,HRX_MSA_COORDS_PDP ,LY_HRX_MSA_COORDS_PDP ],
    [HRX_MSA_TRACKSUITS_REVENUE,LY_HRX_MSA_TRACKSUITS_REVENUE,HRX_MSA_TRACKSUITS_GM_PERCENTAGE,LY_HRX_MSA_TRACKSUITS_GM_PERCENTAGE,HRX_MSA_TRACKSUITS_TD_PERCENTAGE
,LY_HRX_MSA_TRACKSUITS_TD_PERCENTAGE,HRX_MSA_TRACKSUITS_QTY,LY_HRX_MSA_TRACKSUITS_QTY,HRX_MSA_TRACKSUITS_AVG_MRP,LY_HRX_MSA_TRACKSUITS_AVG_MRP,HRX_MSA_TRACKSUITS_AVG_ISP
,LY_HRX_MSA_TRACKSUITS_AVG_ISP,HRX_MSA_TRACKSUITS_LC ,LY_HRX_MSA_TRACKSUITS_LC ,HRX_MSA_TRACKSUITS_PDP ,LY_HRX_MSA_TRACKSUITS_PDP ],
    [HRX_MSA_JACKETS_REVENUE,LY_HRX_MSA_JACKETS_REVENUE,HRX_MSA_JACKETS_GM_PERCENTAGE,LY_HRX_MSA_JACKETS_GM_PERCENTAGE,HRX_MSA_JACKETS_TD_PERCENTAGE
,LY_HRX_MSA_JACKETS_TD_PERCENTAGE,HRX_MSA_JACKETS_QTY,LY_HRX_MSA_JACKETS_QTY,HRX_MSA_JACKETS_AVG_MRP,LY_HRX_MSA_JACKETS_AVG_MRP,HRX_MSA_JACKETS_AVG_ISP
,LY_HRX_MSA_JACKETS_AVG_ISP,HRX_MSA_JACKETS_LC ,LY_HRX_MSA_JACKETS_LC ,HRX_MSA_JACKETS_PDP ,LY_HRX_MSA_JACKETS_PDP ],
    [HRX_MSA_SWEATSHIRTS_REVENUE,LY_HRX_MSA_SWEATSHIRTS_REVENUE,HRX_MSA_SWEATSHIRTS_GM_PERCENTAGE,LY_HRX_MSA_SWEATSHIRTS_GM_PERCENTAGE,HRX_MSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_HRX_MSA_SWEATSHIRTS_TD_PERCENTAGE,HRX_MSA_SWEATSHIRTS_QTY,LY_HRX_MSA_SWEATSHIRTS_QTY,HRX_MSA_SWEATSHIRTS_AVG_MRP,LY_HRX_MSA_SWEATSHIRTS_AVG_MRP,
HRX_MSA_SWEATSHIRTS_AVG_ISP,LY_HRX_MSA_SWEATSHIRTS_AVG_ISP,HRX_MSA_SWEATSHIRTS_LC ,LY_HRX_MSA_SWEATSHIRTS_LC ,HRX_MSA_SWEATSHIRTS_PDP ,LY_HRX_MSA_SWEATSHIRTS_PDP ],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [HRX_WSA_TSHIRTS_REVENUE,LY_HRX_WSA_TSHIRTS_REVENUE,HRX_WSA_TSHIRTS_GM_PERCENTAGE,LY_HRX_WSA_TSHIRTS_GM_PERCENTAGE,HRX_WSA_TSHIRTS_TD_PERCENTAGE
,LY_HRX_WSA_TSHIRTS_TD_PERCENTAGE,HRX_WSA_TSHIRTS_QTY,LY_HRX_WSA_TSHIRTS_QTY,HRX_WSA_TSHIRTS_AVG_MRP,LY_HRX_WSA_TSHIRTS_AVG_MRP,HRX_WSA_TSHIRTS_AVG_ISP
,LY_HRX_WSA_TSHIRTS_AVG_ISP,HRX_WSA_TSHIRTS_LC ,LY_HRX_WSA_TSHIRTS_LC,HRX_WSA_TSHIRTS_PDP ,LY_HRX_WSA_TSHIRTS_PDP  ],
    [HRX_WSA_TIGHTS_REVENUE,LY_HRX_WSA_TIGHTS_REVENUE,HRX_WSA_TIGHTS_GM_PERCENTAGE,LY_HRX_WSA_TIGHTS_GM_PERCENTAGE,HRX_WSA_TIGHTS_TD_PERCENTAGE
,LY_HRX_WSA_TIGHTS_TD_PERCENTAGE,HRX_WSA_TIGHTS_QTY,LY_HRX_WSA_TIGHTS_QTY,HRX_WSA_TIGHTS_AVG_MRP,LY_HRX_WSA_TIGHTS_AVG_MRP,HRX_WSA_TIGHTS_AVG_ISP
,LY_HRX_WSA_TIGHTS_AVG_ISP,HRX_WSA_TIGHTS_LC ,LY_HRX_WSA_TIGHTS_LC ,HRX_WSA_TIGHTS_PDP ,LY_HRX_WSA_TIGHTS_PDP ],
    [HRX_WSA_TRACKPANTS_REVENUE,LY_HRX_WSA_TRACKPANTS_REVENUE,HRX_WSA_TRACKPANTS_GM_PERCENTAGE,LY_HRX_WSA_TRACKPANTS_GM_PERCENTAGE,HRX_WSA_TRACKPANTS_TD_PERCENTAGE
,LY_HRX_WSA_TRACKPANTS_TD_PERCENTAGE,HRX_WSA_TRACKPANTS_QTY,LY_HRX_WSA_TRACKPANTS_QTY,HRX_WSA_TRACKPANTS_AVG_MRP,LY_HRX_WSA_TRACKPANTS_AVG_MRP,HRX_WSA_TRACKPANTS_AVG_ISP
,LY_HRX_WSA_TRACKPANTS_AVG_ISP,HRX_WSA_TRACKPANTS_LC ,LY_HRX_WSA_TRACKPANTS_LC ,HRX_WSA_TRACKPANTS_PDP ,LY_HRX_WSA_TRACKPANTS_PDP ],
    [HRX_WSA_BRA_REVENUE,LY_HRX_WSA_BRA_REVENUE,HRX_WSA_BRA_GM_PERCENTAGE,LY_HRX_WSA_BRA_GM_PERCENTAGE,HRX_WSA_BRA_TD_PERCENTAGE
,LY_HRX_WSA_BRA_TD_PERCENTAGE,HRX_WSA_BRA_QTY,LY_HRX_WSA_BRA_QTY,HRX_WSA_BRA_AVG_MRP,LY_HRX_WSA_BRA_AVG_MRP,HRX_WSA_BRA_AVG_ISP,LY_HRX_WSA_BRA_AVG_ISP,
    HRX_WSA_BRA_LC ,LY_HRX_WSA_BRA_LC ,HRX_WSA_BRA_PDP ,LY_HRX_WSA_BRA_PDP ],
    [HRX_WSA_SHORTS_REVENUE,LY_HRX_WSA_SHORTS_REVENUE,HRX_WSA_SHORTS_GM_PERCENTAGE,LY_HRX_WSA_SHORTS_GM_PERCENTAGE,HRX_WSA_SHORTS_TD_PERCENTAGE
,LY_HRX_WSA_SHORTS_TD_PERCENTAGE,HRX_WSA_SHORTS_QTY,LY_HRX_WSA_SHORTS_QTY,HRX_WSA_SHORTS_AVG_MRP,LY_HRX_WSA_SHORTS_AVG_MRP,HRX_WSA_SHORTS_AVG_ISP
,LY_HRX_WSA_SHORTS_AVG_ISP,HRX_WSA_SHORTS_LC ,LY_HRX_WSA_SHORTS_LC ,HRX_WSA_SHORTS_PDP ,LY_HRX_WSA_SHORTS_PDP ],
    [HRX_WSA_TOPS_REVENUE,LY_HRX_WSA_TOPS_REVENUE,HRX_WSA_TOPS_GM_PERCENTAGE,LY_HRX_WSA_TOPS_GM_PERCENTAGE,HRX_WSA_TOPS_TD_PERCENTAGE
,LY_HRX_WSA_TOPS_TD_PERCENTAGE,HRX_WSA_TOPS_QTY,LY_HRX_WSA_TOPS_QTY,HRX_WSA_TOPS_AVG_MRP,LY_HRX_WSA_TOPS_AVG_MRP,HRX_WSA_TOPS_AVG_ISP,LY_HRX_WSA_TOPS_AVG_ISP,
    HRX_WSA_TOPS_LC ,LY_HRX_WSA_TOPS_LC ,HRX_WSA_TOPS_PDP ,LY_HRX_WSA_TOPS_PDP ],
    [HRX_WSA_TROUSERS_REVENUE,LY_HRX_WSA_TROUSERS_REVENUE,HRX_WSA_TROUSERS_GM_PERCENTAGE,LY_HRX_WSA_TROUSERS_GM_PERCENTAGE,HRX_WSA_TROUSERS_TD_PERCENTAGE
,LY_HRX_WSA_TROUSERS_TD_PERCENTAGE,HRX_WSA_TROUSERS_QTY,LY_HRX_WSA_TROUSERS_QTY,HRX_WSA_TROUSERS_AVG_MRP,LY_HRX_WSA_TROUSERS_AVG_MRP,HRX_WSA_TROUSERS_AVG_ISP
,LY_HRX_WSA_TROUSERS_AVG_ISP,HRX_WSA_TROUSERS_LC ,LY_HRX_WSA_TROUSERS_LC ,HRX_WSA_TROUSERS_PDP ,LY_HRX_WSA_TROUSERS_PDP ],
    [HRX_WSA_TRACKSUITS_REVENUE,LY_HRX_WSA_TRACKSUITS_REVENUE,HRX_WSA_TRACKSUITS_GM_PERCENTAGE,LY_HRX_WSA_TRACKSUITS_GM_PERCENTAGE,HRX_WSA_TRACKSUITS_TD_PERCENTAGE
,LY_HRX_WSA_TRACKSUITS_TD_PERCENTAGE,HRX_WSA_TRACKSUITS_QTY,LY_HRX_WSA_TRACKSUITS_QTY,HRX_WSA_TRACKSUITS_AVG_MRP,LY_HRX_WSA_TRACKSUITS_AVG_MRP,
HRX_WSA_TRACKSUITS_AVG_ISP,LY_HRX_WSA_TRACKSUITS_AVG_ISP,HRX_WSA_TRACKSUITS_LC ,LY_HRX_WSA_TRACKSUITS_LC ,HRX_WSA_TRACKSUITS_PDP ,LY_HRX_WSA_TRACKSUITS_PDP ],
    [HRX_WSA_JACKETS_REVENUE,LY_HRX_WSA_JACKETS_REVENUE,HRX_WSA_JACKETS_GM_PERCENTAGE,LY_HRX_WSA_JACKETS_GM_PERCENTAGE,HRX_WSA_JACKETS_TD_PERCENTAGE
,LY_HRX_WSA_JACKETS_TD_PERCENTAGE,HRX_WSA_JACKETS_QTY,LY_HRX_WSA_JACKETS_QTY,HRX_WSA_JACKETS_AVG_MRP,LY_HRX_WSA_JACKETS_AVG_MRP,HRX_WSA_JACKETS_AVG_ISP
,LY_HRX_WSA_JACKETS_AVG_ISP,HRX_WSA_JACKETS_LC ,LY_HRX_WSA_JACKETS_LC ,HRX_WSA_JACKETS_PDP ,LY_HRX_WSA_JACKETS_PDP ],
    [HRX_WSA_SWEATSHIRTS_REVENUE,LY_HRX_WSA_SWEATSHIRTS_REVENUE,HRX_WSA_SWEATSHIRTS_GM_PERCENTAGE,LY_HRX_WSA_SWEATSHIRTS_GM_PERCENTAGE,HRX_WSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_HRX_WSA_SWEATSHIRTS_TD_PERCENTAGE,HRX_WSA_SWEATSHIRTS_QTY,LY_HRX_WSA_SWEATSHIRTS_QTY,HRX_WSA_SWEATSHIRTS_AVG_MRP,LY_HRX_WSA_SWEATSHIRTS_AVG_MRP,
HRX_WSA_SWEATSHIRTS_AVG_ISP,LY_HRX_WSA_SWEATSHIRTS_AVG_ISP,HRX_WSA_SWEATSHIRTS_LC ,LY_HRX_WSA_SWEATSHIRTS_LC ,HRX_WSA_SWEATSHIRTS_PDP ,LY_HRX_WSA_SWEATSHIRTS_PDP ],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [OR_MSA_TSHIRTS_REVENUE,LY_OR_MSA_TSHIRTS_REVENUE,OR_MSA_TSHIRTS_GM_PERCENTAGE,LY_OR_MSA_TSHIRTS_GM_PERCENTAGE,OR_MSA_TSHIRTS_TD_PERCENTAGE
,LY_OR_MSA_TSHIRTS_TD_PERCENTAGE,OR_MSA_TSHIRTS_QTY,LY_OR_MSA_TSHIRTS_QTY,OR_MSA_TSHIRTS_AVG_MRP,LY_OR_MSA_TSHIRTS_AVG_MRP,OR_MSA_TSHIRTS_AVG_ISP
,LY_OR_MSA_TSHIRTS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_TRACKPANTS_REVENUE,LY_OR_MSA_TRACKPANTS_REVENUE,OR_MSA_TRACKPANTS_GM_PERCENTAGE,LY_OR_MSA_TRACKPANTS_GM_PERCENTAGE,OR_MSA_TRACKPANTS_TD_PERCENTAGE
,LY_OR_MSA_TRACKPANTS_TD_PERCENTAGE,OR_MSA_TRACKPANTS_QTY,LY_OR_MSA_TRACKPANTS_QTY,OR_MSA_TRACKPANTS_AVG_MRP,LY_OR_MSA_TRACKPANTS_AVG_MRP,OR_MSA_TRACKPANTS_AVG_ISP
,LY_OR_MSA_TRACKPANTS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_SHORTS_REVENUE,LY_OR_MSA_SHORTS_REVENUE,OR_MSA_SHORTS_GM_PERCENTAGE,LY_OR_MSA_SHORTS_GM_PERCENTAGE,OR_MSA_SHORTS_TD_PERCENTAGE
,LY_OR_MSA_SHORTS_TD_PERCENTAGE,OR_MSA_SHORTS_QTY,LY_OR_MSA_SHORTS_QTY,OR_MSA_SHORTS_AVG_MRP,LY_OR_MSA_SHORTS_AVG_MRP,OR_MSA_SHORTS_AVG_ISP
,LY_OR_MSA_SHORTS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_TIGHTS_REVENUE,LY_OR_MSA_TIGHTS_REVENUE,OR_MSA_TIGHTS_GM_PERCENTAGE,LY_OR_MSA_TIGHTS_GM_PERCENTAGE,OR_MSA_TIGHTS_TD_PERCENTAGE
,LY_OR_MSA_TIGHTS_TD_PERCENTAGE,OR_MSA_TIGHTS_QTY,LY_OR_MSA_TIGHTS_QTY,OR_MSA_TIGHTS_AVG_MRP,LY_OR_MSA_TIGHTS_AVG_MRP,OR_MSA_TIGHTS_AVG_ISP
,LY_OR_MSA_TIGHTS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_TRACKSUITS_REVENUE,LY_OR_MSA_TRACKSUITS_REVENUE,OR_MSA_TRACKSUITS_GM_PERCENTAGE,LY_OR_MSA_TRACKSUITS_GM_PERCENTAGE,OR_MSA_TRACKSUITS_TD_PERCENTAGE
,LY_OR_MSA_TRACKSUITS_TD_PERCENTAGE,OR_MSA_TRACKSUITS_QTY,LY_OR_MSA_TRACKSUITS_QTY,OR_MSA_TRACKSUITS_AVG_MRP,LY_OR_MSA_TRACKSUITS_AVG_MRP,OR_MSA_TRACKSUITS_AVG_ISP
,LY_OR_MSA_TRACKSUITS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_JACKETS_REVENUE,LY_OR_MSA_JACKETS_REVENUE,OR_MSA_JACKETS_GM_PERCENTAGE,LY_OR_MSA_JACKETS_GM_PERCENTAGE,OR_MSA_JACKETS_TD_PERCENTAGE
,LY_OR_MSA_JACKETS_TD_PERCENTAGE,OR_MSA_JACKETS_QTY,LY_OR_MSA_JACKETS_QTY,OR_MSA_JACKETS_AVG_MRP,LY_OR_MSA_JACKETS_AVG_MRP,OR_MSA_JACKETS_AVG_ISP
,LY_OR_MSA_JACKETS_AVG_ISP,'-','-','-','-'],
    [OR_MSA_SWEATSHIRTS_REVENUE,LY_OR_MSA_SWEATSHIRTS_REVENUE,OR_MSA_SWEATSHIRTS_GM_PERCENTAGE,LY_OR_MSA_SWEATSHIRTS_GM_PERCENTAGE,OR_MSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_OR_MSA_SWEATSHIRTS_TD_PERCENTAGE,OR_MSA_SWEATSHIRTS_QTY,LY_OR_MSA_SWEATSHIRTS_QTY,OR_MSA_SWEATSHIRTS_AVG_MRP,LY_OR_MSA_SWEATSHIRTS_AVG_MRP,OR_MSA_SWEATSHIRTS_AVG_ISP
,LY_OR_MSA_SWEATSHIRTS_AVG_ISP,'-','-','-','-'],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [OR_WSA_TSHIRTS_REVENUE,LY_OR_WSA_TSHIRTS_REVENUE,OR_WSA_TSHIRTS_GM_PERCENTAGE,LY_OR_WSA_TSHIRTS_GM_PERCENTAGE,OR_WSA_TSHIRTS_TD_PERCENTAGE
,LY_OR_WSA_TSHIRTS_TD_PERCENTAGE,OR_WSA_TSHIRTS_QTY,LY_OR_WSA_TSHIRTS_QTY,OR_WSA_TSHIRTS_AVG_MRP,LY_OR_WSA_TSHIRTS_AVG_MRP,OR_WSA_TSHIRTS_AVG_ISP
,LY_OR_WSA_TSHIRTS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_TIGHTS_REVENUE,LY_OR_WSA_TIGHTS_REVENUE,OR_WSA_TIGHTS_GM_PERCENTAGE,LY_OR_WSA_TIGHTS_GM_PERCENTAGE,OR_WSA_TIGHTS_TD_PERCENTAGE
,LY_OR_WSA_TIGHTS_TD_PERCENTAGE,OR_WSA_TIGHTS_QTY,LY_OR_WSA_TIGHTS_QTY,OR_WSA_TIGHTS_AVG_MRP,LY_OR_WSA_TIGHTS_AVG_MRP,OR_WSA_TIGHTS_AVG_ISP
,LY_OR_WSA_TIGHTS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_TRACKPANTS_REVENUE,LY_OR_WSA_TRACKPANTS_REVENUE,OR_WSA_TRACKPANTS_GM_PERCENTAGE,LY_OR_WSA_TRACKPANTS_GM_PERCENTAGE,OR_WSA_TRACKPANTS_TD_PERCENTAGE
,LY_OR_WSA_TRACKPANTS_TD_PERCENTAGE,OR_WSA_TRACKPANTS_QTY,LY_OR_WSA_TRACKPANTS_QTY,OR_WSA_TRACKPANTS_AVG_MRP,LY_OR_WSA_TRACKPANTS_AVG_MRP,OR_WSA_TRACKPANTS_AVG_ISP
,LY_OR_WSA_TRACKPANTS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_BRA_REVENUE,LY_OR_WSA_BRA_REVENUE,OR_WSA_BRA_GM_PERCENTAGE,LY_OR_WSA_BRA_GM_PERCENTAGE,OR_WSA_BRA_TD_PERCENTAGE
,LY_OR_WSA_BRA_TD_PERCENTAGE,OR_WSA_BRA_QTY,LY_OR_WSA_BRA_QTY,OR_WSA_BRA_AVG_MRP,LY_OR_WSA_BRA_AVG_MRP,OR_WSA_BRA_AVG_ISP,LY_OR_WSA_BRA_AVG_ISP,'-','-','-','-'],
    [OR_WSA_SHORTS_REVENUE,LY_OR_WSA_SHORTS_REVENUE,OR_WSA_SHORTS_GM_PERCENTAGE,LY_OR_WSA_SHORTS_GM_PERCENTAGE,OR_WSA_SHORTS_TD_PERCENTAGE
,LY_OR_WSA_SHORTS_TD_PERCENTAGE,OR_WSA_SHORTS_QTY,LY_OR_WSA_SHORTS_QTY,OR_WSA_SHORTS_AVG_MRP,LY_OR_WSA_SHORTS_AVG_MRP,OR_WSA_SHORTS_AVG_ISP
,LY_OR_WSA_SHORTS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_TOPS_REVENUE,LY_OR_WSA_TOPS_REVENUE,OR_WSA_TOPS_GM_PERCENTAGE,LY_OR_WSA_TOPS_GM_PERCENTAGE,OR_WSA_TOPS_TD_PERCENTAGE
,LY_OR_WSA_TOPS_TD_PERCENTAGE,OR_WSA_TOPS_QTY,LY_OR_WSA_TOPS_QTY,OR_WSA_TOPS_AVG_MRP,LY_OR_WSA_TOPS_AVG_MRP,OR_WSA_TOPS_AVG_ISP,LY_OR_WSA_TOPS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_TROUSERS_REVENUE,LY_OR_WSA_TROUSERS_REVENUE,OR_WSA_TROUSERS_GM_PERCENTAGE,LY_OR_WSA_TROUSERS_GM_PERCENTAGE,OR_WSA_TROUSERS_TD_PERCENTAGE
,LY_OR_WSA_TROUSERS_TD_PERCENTAGE,OR_WSA_TROUSERS_QTY,LY_OR_WSA_TROUSERS_QTY,OR_WSA_TROUSERS_AVG_MRP,LY_OR_WSA_TROUSERS_AVG_MRP,OR_WSA_TROUSERS_AVG_ISP
,LY_OR_WSA_TROUSERS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_TRACKSUITS_REVENUE,LY_OR_WSA_TRACKSUITS_REVENUE,OR_WSA_TRACKSUITS_GM_PERCENTAGE,LY_OR_WSA_TRACKSUITS_GM_PERCENTAGE,OR_WSA_TRACKSUITS_TD_PERCENTAGE
,LY_OR_WSA_TRACKSUITS_TD_PERCENTAGE,OR_WSA_TRACKSUITS_QTY,LY_OR_WSA_TRACKSUITS_QTY,OR_WSA_TRACKSUITS_AVG_MRP,LY_OR_WSA_TRACKSUITS_AVG_MRP,OR_WSA_TRACKSUITS_AVG_ISP
,LY_OR_WSA_TRACKSUITS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_JACKETS_REVENUE,LY_OR_WSA_JACKETS_REVENUE,OR_WSA_JACKETS_GM_PERCENTAGE,LY_OR_WSA_JACKETS_GM_PERCENTAGE,OR_WSA_JACKETS_TD_PERCENTAGE
,LY_OR_WSA_JACKETS_TD_PERCENTAGE,OR_WSA_JACKETS_QTY,LY_OR_WSA_JACKETS_QTY,OR_WSA_JACKETS_AVG_MRP,LY_OR_WSA_JACKETS_AVG_MRP,OR_WSA_JACKETS_AVG_ISP
,LY_OR_WSA_JACKETS_AVG_ISP,'-','-','-','-'],
    [OR_WSA_SWEATSHIRTS_REVENUE,LY_OR_WSA_SWEATSHIRTS_REVENUE,OR_WSA_SWEATSHIRTS_GM_PERCENTAGE,LY_OR_WSA_SWEATSHIRTS_GM_PERCENTAGE,OR_WSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_OR_WSA_SWEATSHIRTS_TD_PERCENTAGE,OR_WSA_SWEATSHIRTS_QTY,LY_OR_WSA_SWEATSHIRTS_QTY,OR_WSA_SWEATSHIRTS_AVG_MRP,LY_OR_WSA_SWEATSHIRTS_AVG_MRP,OR_WSA_SWEATSHIRTS_AVG_ISP
,LY_OR_WSA_SWEATSHIRTS_AVG_ISP,'-','-','-','-'],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [MP_MSA_TSHIRTS_REVENUE,LY_MP_MSA_TSHIRTS_REVENUE,MP_MSA_TSHIRTS_GM_PERCENTAGE,LY_MP_MSA_TSHIRTS_GM_PERCENTAGE,MP_MSA_TSHIRTS_TD_PERCENTAGE
,LY_MP_MSA_TSHIRTS_TD_PERCENTAGE,MP_MSA_TSHIRTS_QTY,LY_MP_MSA_TSHIRTS_QTY,MP_MSA_TSHIRTS_AVG_MRP,LY_MP_MSA_TSHIRTS_AVG_MRP,MP_MSA_TSHIRTS_AVG_ISP
,LY_MP_MSA_TSHIRTS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_TRACKPANTS_REVENUE,LY_MP_MSA_TRACKPANTS_REVENUE,MP_MSA_TRACKPANTS_GM_PERCENTAGE,LY_MP_MSA_TRACKPANTS_GM_PERCENTAGE,MP_MSA_TRACKPANTS_TD_PERCENTAGE
,LY_MP_MSA_TRACKPANTS_TD_PERCENTAGE,MP_MSA_TRACKPANTS_QTY,LY_MP_MSA_TRACKPANTS_QTY,MP_MSA_TRACKPANTS_AVG_MRP,LY_MP_MSA_TRACKPANTS_AVG_MRP,MP_MSA_TRACKPANTS_AVG_ISP
,LY_MP_MSA_TRACKPANTS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_SHORTS_REVENUE,LY_MP_MSA_SHORTS_REVENUE,MP_MSA_SHORTS_GM_PERCENTAGE,LY_MP_MSA_SHORTS_GM_PERCENTAGE,MP_MSA_SHORTS_TD_PERCENTAGE
,LY_MP_MSA_SHORTS_TD_PERCENTAGE,MP_MSA_SHORTS_QTY,LY_MP_MSA_SHORTS_QTY,MP_MSA_SHORTS_AVG_MRP,LY_MP_MSA_SHORTS_AVG_MRP,MP_MSA_SHORTS_AVG_ISP
,LY_MP_MSA_SHORTS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_TIGHTS_REVENUE,LY_MP_MSA_TIGHTS_REVENUE,MP_MSA_TIGHTS_GM_PERCENTAGE,LY_MP_MSA_TIGHTS_GM_PERCENTAGE,MP_MSA_TIGHTS_TD_PERCENTAGE
,LY_MP_MSA_TIGHTS_TD_PERCENTAGE,MP_MSA_TIGHTS_QTY,LY_MP_MSA_TIGHTS_QTY,MP_MSA_TIGHTS_AVG_MRP,LY_MP_MSA_TIGHTS_AVG_MRP,MP_MSA_TIGHTS_AVG_ISP
,LY_MP_MSA_TIGHTS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_TRACKSUITS_REVENUE,LY_MP_MSA_TRACKSUITS_REVENUE,MP_MSA_TRACKSUITS_GM_PERCENTAGE,LY_MP_MSA_TRACKSUITS_GM_PERCENTAGE,MP_MSA_TRACKSUITS_TD_PERCENTAGE
,LY_MP_MSA_TRACKSUITS_TD_PERCENTAGE,MP_MSA_TRACKSUITS_QTY,LY_MP_MSA_TRACKSUITS_QTY,MP_MSA_TRACKSUITS_AVG_MRP,LY_MP_MSA_TRACKSUITS_AVG_MRP,MP_MSA_TRACKSUITS_AVG_ISP
,LY_MP_MSA_TRACKSUITS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_JACKETS_REVENUE,LY_MP_MSA_JACKETS_REVENUE,MP_MSA_JACKETS_GM_PERCENTAGE,LY_MP_MSA_JACKETS_GM_PERCENTAGE,MP_MSA_JACKETS_TD_PERCENTAGE
,LY_MP_MSA_JACKETS_TD_PERCENTAGE,MP_MSA_JACKETS_QTY,LY_MP_MSA_JACKETS_QTY,MP_MSA_JACKETS_AVG_MRP,LY_MP_MSA_JACKETS_AVG_MRP,MP_MSA_JACKETS_AVG_ISP
,LY_MP_MSA_JACKETS_AVG_ISP,'-','-','-','-'],
    [MP_MSA_SWEATSHIRTS_REVENUE,LY_MP_MSA_SWEATSHIRTS_REVENUE,MP_MSA_SWEATSHIRTS_GM_PERCENTAGE,LY_MP_MSA_SWEATSHIRTS_GM_PERCENTAGE,MP_MSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_MP_MSA_SWEATSHIRTS_TD_PERCENTAGE,MP_MSA_SWEATSHIRTS_QTY,LY_MP_MSA_SWEATSHIRTS_QTY,MP_MSA_SWEATSHIRTS_AVG_MRP,LY_MP_MSA_SWEATSHIRTS_AVG_MRP,MP_MSA_SWEATSHIRTS_AVG_ISP
,LY_MP_MSA_SWEATSHIRTS_AVG_ISP,'-','-','-','-'],
    ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-','-'],
    [MP_WSA_TSHIRTS_REVENUE,LY_MP_WSA_TSHIRTS_REVENUE,MP_WSA_TSHIRTS_GM_PERCENTAGE,LY_MP_WSA_TSHIRTS_GM_PERCENTAGE,MP_WSA_TSHIRTS_TD_PERCENTAGE
,LY_MP_WSA_TSHIRTS_TD_PERCENTAGE,MP_WSA_TSHIRTS_QTY,LY_MP_WSA_TSHIRTS_QTY,MP_WSA_TSHIRTS_AVG_MRP,LY_MP_WSA_TSHIRTS_AVG_MRP,MP_WSA_TSHIRTS_AVG_ISP
,LY_MP_WSA_TSHIRTS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_TIGHTS_REVENUE,LY_MP_WSA_TIGHTS_REVENUE,MP_WSA_TIGHTS_GM_PERCENTAGE,LY_MP_WSA_TIGHTS_GM_PERCENTAGE,MP_WSA_TIGHTS_TD_PERCENTAGE
,LY_MP_WSA_TIGHTS_TD_PERCENTAGE,MP_WSA_TIGHTS_QTY,LY_MP_WSA_TIGHTS_QTY,MP_WSA_TIGHTS_AVG_MRP,LY_MP_WSA_TIGHTS_AVG_MRP,MP_WSA_TIGHTS_AVG_ISP
,LY_MP_WSA_TIGHTS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_TRACKPANTS_REVENUE,LY_MP_WSA_TRACKPANTS_REVENUE,MP_WSA_TRACKPANTS_GM_PERCENTAGE,LY_MP_WSA_TRACKPANTS_GM_PERCENTAGE,MP_WSA_TRACKPANTS_TD_PERCENTAGE
,LY_MP_WSA_TRACKPANTS_TD_PERCENTAGE,MP_WSA_TRACKPANTS_QTY,LY_MP_WSA_TRACKPANTS_QTY,MP_WSA_TRACKPANTS_AVG_MRP,LY_MP_WSA_TRACKPANTS_AVG_MRP,MP_WSA_TRACKPANTS_AVG_ISP
,LY_MP_WSA_TRACKPANTS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_BRA_REVENUE,LY_MP_WSA_BRA_REVENUE,MP_WSA_BRA_GM_PERCENTAGE,LY_MP_WSA_BRA_GM_PERCENTAGE,MP_WSA_BRA_TD_PERCENTAGE
,LY_MP_WSA_BRA_TD_PERCENTAGE,MP_WSA_BRA_QTY,LY_MP_WSA_BRA_QTY,MP_WSA_BRA_AVG_MRP,LY_MP_WSA_BRA_AVG_MRP,MP_WSA_BRA_AVG_ISP
,LY_MP_WSA_BRA_AVG_ISP,'-','-','-','-'],
    [MP_WSA_SHORTS_REVENUE,LY_MP_WSA_SHORTS_REVENUE,MP_WSA_SHORTS_GM_PERCENTAGE,LY_MP_WSA_SHORTS_GM_PERCENTAGE,MP_WSA_SHORTS_TD_PERCENTAGE
,LY_MP_WSA_SHORTS_TD_PERCENTAGE,MP_WSA_SHORTS_QTY,LY_MP_WSA_SHORTS_QTY,MP_WSA_SHORTS_AVG_MRP,LY_MP_WSA_SHORTS_AVG_MRP,MP_WSA_SHORTS_AVG_ISP,LY_MP_WSA_SHORTS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_TOPS_REVENUE,LY_MP_WSA_TOPS_REVENUE,MP_WSA_TOPS_GM_PERCENTAGE,LY_MP_WSA_TOPS_GM_PERCENTAGE,MP_WSA_TOPS_TD_PERCENTAGE
,LY_MP_WSA_TOPS_TD_PERCENTAGE,MP_WSA_TOPS_QTY,LY_MP_WSA_TOPS_QTY,MP_WSA_TOPS_AVG_MRP,LY_MP_WSA_TOPS_AVG_MRP,MP_WSA_TOPS_AVG_ISP,LY_MP_WSA_TOPS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_TRACKSUITS_REVENUE,LY_MP_WSA_TRACKSUITS_REVENUE,MP_WSA_TRACKSUITS_GM_PERCENTAGE,LY_MP_WSA_TRACKSUITS_GM_PERCENTAGE,MP_WSA_TRACKSUITS_TD_PERCENTAGE
,LY_MP_WSA_TRACKSUITS_TD_PERCENTAGE,MP_WSA_TRACKSUITS_QTY,LY_MP_WSA_TRACKSUITS_QTY,MP_WSA_TRACKSUITS_AVG_MRP,LY_MP_WSA_TRACKSUITS_AVG_MRP,MP_WSA_TRACKSUITS_AVG_ISP
,LY_MP_WSA_TRACKSUITS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_JACKETS_REVENUE,LY_MP_WSA_JACKETS_REVENUE,MP_WSA_JACKETS_GM_PERCENTAGE,LY_MP_WSA_JACKETS_GM_PERCENTAGE,MP_WSA_JACKETS_TD_PERCENTAGE
,LY_MP_WSA_JACKETS_TD_PERCENTAGE,MP_WSA_JACKETS_QTY,LY_MP_WSA_JACKETS_QTY,MP_WSA_JACKETS_AVG_MRP,LY_MP_WSA_JACKETS_AVG_MRP,MP_WSA_JACKETS_AVG_ISP
,LY_MP_WSA_JACKETS_AVG_ISP,'-','-','-','-'],
    [MP_WSA_SWEATSHIRTS_REVENUE,LY_MP_WSA_SWEATSHIRTS_REVENUE,MP_WSA_SWEATSHIRTS_GM_PERCENTAGE,LY_MP_WSA_SWEATSHIRTS_GM_PERCENTAGE,MP_WSA_SWEATSHIRTS_TD_PERCENTAGE
,LY_MP_WSA_SWEATSHIRTS_TD_PERCENTAGE,MP_WSA_SWEATSHIRTS_QTY,LY_MP_WSA_SWEATSHIRTS_QTY,MP_WSA_SWEATSHIRTS_AVG_MRP,LY_MP_WSA_SWEATSHIRTS_AVG_MRP,MP_WSA_SWEATSHIRTS_AVG_ISP
,LY_MP_WSA_SWEATSHIRTS_AVG_ISP,'-','-','-','-']
]

df = pd.DataFrame(metrics, index=['Platform total','MMB','MFB','-','Sports Wear (MSA+WSA)',"Men's Sports Apparel","Women's Sports Apparel",
     '-','HRX Total','HRX OR','HRX MP',"HRX Men's Sports Apparel","HRX Women's Sports Apparel","HRX M+W Total",'-','HRX-M OR','HRX-M MP','-',
     'HRX-W OR','HRX-W MP','-','Men-Tshirts','Men-Track Pants','Men-Shorts','Men-Co-ords','Men-Tracksuits','Men-Jackets','Men-Sweatshirts','-',
     'Women-Tshirts','Women-Tights','Women-Track Pants','Women-Bra','Women-Shorts','Women-Tops','Women-Trousers','Women-Tracksuits','Women-Jackets',
     'Women-Sweatshirts','-','OR-Men-Tshirts','OR-Men-Track Pants','OR-Men-Shorts','OR-Men-Tights','OR-Men-Tracksuits','OR-Men-Jackets',
     'OR-Men-Sweatshirts','-','OR-Women-Tshirts','OR-Women-Tights','OR-Women-Track Pants','OR-Women-Bra','OR-Women-Shorts','OR-Women-Tops',
     'OR-Women-Trousers','OR-Women-Tracksuits','OR-Women-Jackets','OR-Women-Sweatshirts','-','MP-Men-Tshirts','MP-Men-Track Pants','MP-Men-Shorts','MP-Men-Tights',
     'MP-Men-Tracksuits','MP-Men-Jackets','MP-Men-Sweatshirts','-','MP-Women-Tshirts','MP-Women-Tights','MP-Women-Track Pants','MP-Women-Bra','MP-Women-Shorts',
     'MP-Women-Tops','MP-Women-Tracksuits','MP-Women-Jackets','MP-Women-Sweatshirts'], 
      columns=['Actual MTD Revenue','LY MTD Revenue','GM Actual%','LY GM%','TD Actual%','LY TD%','Quantity','LY Quantity','AVG MRP','LY AVG MRP',
               'AVG ISP','LY AVG ISP','LV','LY LV','PDP','LY PDP'] )

#df.iloc[-50:]
df.to_excel('FUNNEL-AS-ON-10FEB2025.xlsx')

# %%
v_data.iloc[:1048576]['list_count'].sum()
# Out:
# np.int64(24157083787)
